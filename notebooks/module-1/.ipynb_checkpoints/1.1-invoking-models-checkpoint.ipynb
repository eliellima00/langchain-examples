# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
## Inicializando e invocando um modelo

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model='gpt-5-nano')

# %%
response = model.invoke("What's the capital of the Moon?")

print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re writing fiction, you could invent a capital name like Lunapolis or Selene City. Want a few more fictional options?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# Pretty printing has been turned OFF
