# %%
## Text input

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the capital of the Moon is Lunapolis.
#
# - Location: perched on the sunlit rim of Shackleton Crater near the Moon’s south pole, where the city basks in near‑constant daylight yet sits above shadowy ice reserves just a stone’s throw away.
# - Government: the Lunar Commonwealth’s seat of power, housing the Crescent Council and the Chancellor, who acts as both head of state and commander of lunar defense. Lunapolis is the political heart, while many settlements scatter outward to the ice belts and mineral belts.
# - Architecture: a gleaming landscape of geodesic domes and transparent arcologies connected by glass tunnels. The centerpiece is the Lumen Spire, a towering prism that concentrates solar energy into the city’s power grid and double‑as a time‑keeping beacon.
# - Economy: energy from solar harvesting, water and ice extraction from nearby permanently shadowed craters, lunar‑grade manufacturing, and research in life support, robotics, and in situ resource utilization.
# - Culture: a cosmopolitan blend of engineers, scientists, artists, and miners. The city hosts the Festival of Permanent Day, a grand showcase of light sculpture, holographic theater, and data‑art.
# - Notable features: the Orbital Gate linking Lunapolis to Earth and orbital stations, the Glass Gardens that grow food and oxygen, and subterranean transit hubs protecting residents from radiation and micrometeoroids.
#
# If you want, I can sketch a day in the life of a Lunapolis resident or design a map of the city’s districts.

# %%
## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Screenshot_2.png', 'type': 'image/png', 'size': 72133, 'content': <memory at 0x7f9f782122c0>, 'last_modified': datetime.datetime(2025, 12, 11, 19, 40, 0, 961000, tzinfo=datetime.timezone.utc)},)
