# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Se conectando em um servidor MCP Local

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
                "transport": "stdio",
                "command": "python",
                "args": ["resources/1-mcp-server.py"],
            }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources()

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
# I can create an agent with tools and prompts coming from a MCP Server

from langchain.agents import create_agent

agent = create_agent(
  model="gpt-5-nano",
  tools=tools,
  system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
  {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library")]},
  config=config
)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='6fc02e36-4bda-47d2-b0d2-5e05d7aae89d'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 604, 'prompt_tokens': 271, 'total_tokens': 875, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CxDszTpGcFwci6QKwrqYlaiQcSJzK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bb2c4-4331-7ae1-a921-7059b3238e68-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_CIVzHZEqwe26wbtFAHnoFkHN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 604, 'total_tokens': 875, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "response_time": 0.6,\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.9999956,\n      "raw_content": null\n    },\n    {\n      "url": "https://pypi.org/project/langchain-mcp-tools/",\n      "title": "langchain-mcp-tools - PyPI",\n      "content": "LangChain\'s official LangChain MCP Adapters library, which supports comprehensive integration with LangChain, has been released. You may want to consider using",\n      "score": 0.9999876,\n      "raw_content": null\n    },\n    {\n      "url": "https://www.npmjs.com/package/@langchain/mcp-adapters",\n      "title": "langchain/mcp-adapters - NPM",\n      "content": "import{createAgent} from \\"langchain\\"; import{ChatOpenAI} from\\"@langchain/openai\\"; import{MultiServerMCPClient} from\\"@langchain/mcp-adapters\\";// Create client and connect to server const client = new MultiServerMCPClient({// Global tool configuration options// Whether to throw on errors if a tool fails to load (optional, default: true) throwOnLoadError true,// Whether to prefix tool names with the server name (optional, default: false) prefixToolNameWithServerName false,// Optional additional prefix for tool names (optional, default: \\"\\") additionalToolNamePrefix \\"\\",// Use standardized content block format in tool outputs useStandardContentBlocks true,// Behavior when a server fails to connect: \\"throw\\" (default) or \\"ignore\\" onConnectionError \\"ignore\\",// Server configuration mcpServers{// adds a STDIO connection to a server named \\"math\\" math{transport \\"stdio\\", command \\"npx\\", args[\\"-y\\",\\"@modelcontextprotocol/server-math\\"],// Restart configuration for stdio transport restart{enabled true, maxAttempts 3, delayMs 1000,},},// here\'s a filesystem server filesystem{transport \\"stdio\\", command \\"npx\\", args[\\"-y\\",\\"@modelcontextprotocol/server-filesystem\\"],},// Sreamable HTTP transport example, with auth headers and automatic SSE fallback disabled (defaults to enabled) weather{url\\"https://example.com/weather/mcp\\", headers{Authorization \\"Bearer token123\\",} automaticSSEFallback false},// OAuth 2.0 authentication (recommended for secure servers)\\"oauth-protected-server\\"{url\\"https://protected.example.com/mcp\\", authProvider new MyOAuthProvider({// Your OAuth provider implementation redirectUrl\\"https://myapp.com/oauth/callback\\", clientMetadata{redirect_uris[\\"https://myapp.com/oauth/callback\\"], client_name \\"My MCP Client\\", scope\\"mcp:read mcp:write\\"}}),// Can still include custom headers for non-auth purposes headers{\\"User-Agent\\"\\"My-MCP-Client/1.0\\"}},// how to force SSE, for old servers that are known to only support SSE (streamable ...
#               AIMessage(content='Here’s a concise overview of the langchain-mcp-adapters library and what it’s used for.\n\nWhat it is\n- A library that makes it easy to connect LangChain and LangGraph to the Model Context Protocol (MCP) ecosystem.\n- It converts MCP tools (from MCP servers) into LangChain- and LangGraph-compatible tools.\n- It supports interacting with tools across multiple MCP servers and loading them into LangChain/LangGraph workflows and agents.\n\nWhy you’d use it\n- You can tap into a large and growing set of MCP tool servers without manually adapting each tool.\n- You can aggregate tools from several MCP servers and use them in a single LangChain/LangGraph agent.\n- It simplifies loading MCP-provided tools, prompts, and resources directly into LangChain/LangGraph.\n\nWhere to find it (docs and sources)\n- Python (LangChain content): LangChain MCP Adapters (Python). Reference docs describe MultiServerMCPClient, loading tools, and loading MCP content into LangChain. URL: reference.langchain.com/python/langchain_mcp_adapters/\n- PyPI (Python package): langchain-mcp-tools (the Python package for MCP adapters). URL: https://pypi.org/project/langchain-mcp-tools/\n- Node / JavaScript: @langchain/mcp-adapters (NPM package) with usage examples showing how to instantiate a MultiServerMCPClient and connect to multiple MCP servers. URL: https://www.npmjs.com/package/@langchain/mcp-adapters\n- GitHub (code and examples): langchain-ai/langchain-mcp-adapters. Includes practical examples of using MultiServerMCPClient and integrating with LangChain agents. URL: https://github.com/langchain-ai/langchain-mcp-adapters\n- Announcement / changelog: MCP Adapters for LangChain and LangGraph (high-level overview of what MCP adapters do and why they’re useful). URL: https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph\n\nKey concepts and API highlights\n- MultiServerMCPClient: Central class for managing connections to multiple MCP servers and loading tools/prompts/resources from them.\n- get_tools / load_mcp_tools: Methods to discover and load MCP tools into LangChain/LangGraph workflows.\n- Server definitions: You configure MCP servers (e.g., transport type, URL, auth) and load them into the client. This is demonstrated in the Node example where servers can be stdio-based, HTTP(S) endpoints, or other MCP transports.\n- Tool loading: Tools from MCP servers are loaded so that LangChain agents can call them as if they were native LangChain tools.\n- Cross-server usage: The adapter enables agents to pull tools from multiple MCP servers and use them together.\n\nQuick-start vibe (high-level)\n- Python\n  - pip install langchain-mcp-tools (or the appropriate package per your setup)\n  - Create a MultiServerMCPClient, point it at your MCP servers, and load tools with load_mcp_tools or similar helper functions.\n  - Use the loaded tools in a LangChain agent or workflow as you would with native LangChain tools.\n  - Example usage is shown in the LangChain Python docs for langchain_mcp_adapters.\n- Node\n  - npm install @langchain/mcp-adapters\n  - Instantiate MultiServerMCPClient with your MCP servers (stdio, HTTP, SSE, etc.).\n  - Load tools from MCP servers and attach them to a LangChain agent (e.g., via a standard agent setup).\n\nCommon use cases\n- Building agents that can call a wide array of MCP tool servers (math, filesystem, weather, etc.) across different transports.\n- Creating a single agent workflow that orchestrates tools from multiple MCP servers, potentially with per-server prefixes or metadata.\n- Integrating MCP-based tools into LangGraph-based graphs for more complex orchestration.\n\nWould you like a concrete starter example in Python or JavaScript tailored to your stack (e.g., a minimal script that connects to two MCP servers and loads their tools), or would you prefer a deeper dive into the API surface with code snippets?', additional_kwargs={'refusal': None}, response_metadata={'t ...
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# # Online MCP Server

# %%
client = MultiServerMCPClient(
    {
       "travel_server": {
         "transport": "streamable_http",
         "url": "https://mcp.kiwi.com"
       }
    }
)

tools = await client.get_tools()
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="Get me a direct flight from san francisco to tokyo on March 31st?")

response = await agent.ainvoke(
  {"messages": [question]}
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content='Get me a direct flight from san francisco to tokyo on March 31st?', additional_kwargs={}, response_metadata={}, id='1c871855-a0fb-488f-9750-87ed6ad04b70'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 936, 'prompt_tokens': 1218, 'total_tokens': 2154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CxEB8aqXns6cFOYRyoAyZe0QwXhmm', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bb2d5-691b-7911-baac-6828e7eeb91a-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026'}, 'id': 'call_BZLtiNZASzzQ4BP6xsfV2uEi', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1218, 'output_tokens': 936, 'total_tokens': 2154, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n    "durationInSeconds": 98100,\n    "price": 448,\n    "deepLink": "https://on.kiwi.com/OAhvzP",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 96600,\n    "durationInSeconds": 96600,\n    "price": 448,\n    "deepLink": "https://on.kiwi.com/tQLpSf",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:55:00.000Z",\n      "local": "2026-04-01T12:55:00.000"\n    },\n    "totalDurationInSeconds": 72300,\n    "durationInSeconds": 72300,\n    "price": 497,\n    "deepLink": "https://on.kiwi.com/b85QBk",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:30:00.000Z",\n          "local": "2026-04-01T08:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T18:40:00.000Z",\n      "local": "2026-03-31T11:40:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T05:55:00.000Z",\n      "local": "2026-04-01T14:55:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n    "durationInSeconds": 40500,\n    "price": 680,\n    "deepLink": "https://on.kiwi.com/nFkzdv",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T18:40:00.000Z",\n      "local": "2026-03-31T11:40:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T05:55:00.000Z",\n      "local": "2026-04-01T14:55:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n    "durationInSeconds": 40500,\n    "price": 687,\n    "deepLink": "https://on.kiwi.com/rZ6POV",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:20:00.000Z",\n      "local": "2026-03-31T12:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T06:25:00.000Z",\n      "local": "2026-04-01T15:25:00.000"\n    },\n    "to ...
#               AIMessage(content='Here’s the direct option I found for a San Francisco to Tokyo flight on March 31, 2026:\n\n| Route (including layovers) | Times (local) | Cabin | Return Route | Return Times (local) | Return Cabin | Price | Book link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT (direct) | 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m) | Economy |  |  |  | 408 EUR | https://on.kiwi.com/lfDdiM |\n\nNotes:\n- This is the cheapest direct option found (no layovers).\n- If you’d like, I can also show near-direct options with one or more layovers for comparison, including total travel times and prices. Have a nice trip, and fun fact: Tokyo has hundreds of famous ramen spots—trust me, you’ll find a lot of delicious choices there!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8222, 'prompt_tokens': 6051, 'total_tokens': 14273, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 8000, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CxEBNiiD1DPbBhZPVB1QM19qfRVYz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bb2d5-a3a5-7c20-92a4-68a1841e1abe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6051, 'output_tokens': 8222, 'total_tokens': 14273, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 8000}})]}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(response["messages"][-1].content)
# Out:
# Here’s the direct option I found for a San Francisco to Tokyo flight on March 31, 2026:
#
# | Route (including layovers) | Times (local) | Cabin | Return Route | Return Times (local) | Return Cabin | Price | Book link |
# |---|---|---|---|---|---|---|---|
# | SFO → NRT (direct) | 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m) | Economy |  |  |  | 408 EUR | https://on.kiwi.com/lfDdiM |
#
# Notes:
# - This is the cheapest direct option found (no layovers).
# - If you’d like, I can also show near-direct options with one or more layovers for comparison, including total travel times and prices. Have a nice trip, and fun fact: Tokyo has hundreds of famous ramen spots—trust me, you’ll find a lot of delicious choices there!
