# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from tavily import TavilyClient
tavilyClient = TavilyClient()

# %%
from langchain.tools import tool

@tool()
def search_recipes_by_ingredients(query: str):
  """Searchs recipes by ingredients from WEB"""
  return tavilyClient.search(query)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

config = {"configurable": {"thread_id": "1"}}

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a cousine chief and helps the user to create recipes by their remanescent ingredints.",
    tools=[search_recipes_by_ingredients],
    checkpointer=InMemorySaver()
)

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
import base64 

uploaded_file = uploader.value[0]

content_mv = uploaded_file["content"]

img_bytes = bytes(content_mv)

img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
from langchain.messages import HumanMessage

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Search recipes to me based on this ingredients"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]},
    config
)

print(response['messages'][-1].content)
# Out:
# Encontrei várias opções que trabalham com seus ingredientes (toranja, limão, laranja, kiwi, mirtilos/blueberries, amêndoas, iogurte, mel, gengibre, cúrcuma). Abaixo, as melhores sugestões que aparecem nos resultados, com links e por que se encaixam. Note que muitas são vídeos/imagens com ideias — você pode adaptar para usar todos os ingredientes.
#
# Melhores opções encontradas
# 1) Turmeric Orange Immunity Cubes (cubos de imunidade com cúrcuma e laranja)
# - Link: https://www.instagram.com/reel/C0o7h3Er80g/
# - Por que se encaixa: usa laranja, limão, gengibre, cúrcuma e mel; é fácil adicionar kiwi, mirtilos, iogurte para transformar em uma refeição rápida.
#
# 2) Immunity Shots com cítricos (shot de imunidade)
# - Link: https://www.instagram.com/reel/DSoWgk7DqLc/
# - Por que se encaixa: combina grapefruit, limão, laranja, gengibre e cúrcuma; ótimo para consumo rápido e pode ser adoçado com mel. Você pode adaptar com kiwi e mirtilos.
#
# 3) Juice imunológico cítrico anti-inflamatório (Lemon8-app)
# - Link: https://www.lemon8-app.com/foreignbila/7218965417727967750?region=us
# - Por que se encaixa: menciona limão, gengibre, cúrcuma, laranja e outros cítricos; boa base para um líquido de cleansing que você pode enriquecer com kiwi e mirtilos.
#
# 4) Kiwi Grapefruit Salad | Kowalski's Markets
# - Link: https://www.kowalskis.com/recipes/breakfast-brunch/kiwi-grapefruit-salad?srsltid=AfmBOoolgtERPYvx7ZRROQuffU0VArB9_qLeKQfViCCPTf7UbvxpzqX3
# - Por que se encaixa: kiwi e toranja com iogurte e mel; você pode adicionar mirtilos e amêndoas para ficar mais completo em proteína e crocância.
#
# 5) Post sobre café da manhã imunológico com cítricos (Facebook)
# - Link: https://www.facebook.com/groups/723028768102377/posts/1473206376417942/
# - Por que se encaixa: ideia de tigela de café da manhã com iogurte, suco de limão, cúrcuma; dá para adaptar com grapefruit/orange, kiwi, mirtilos e amêndoas.
#
# Sugestões rápidas de uso
# - Opção 1: tigela de iogurte com cítricos
#   - Base: iogurte, mel a gosto, gengibre ralado, cúrcuma em pó.
#   - Coberturas: kiwi em rodelas, grapefruit e laranja em segmentos, mirtilos, amêndoas picadas.
# - Opção 2: shots ou cubos de imunidade (para 1 porção)
#   - Misture suco de laranja/toranja com gengibre fresco, cúrcuma e um toque de mel. Adicione kiwi picado ao copo antes de beber (ou congele em cubos como os cubos de imunidade).
# - Opção 3: salada cítrica com dressing de iogurte
#   - Combine kiwi, grapefruit, laranja e mirtilos sobre folhas verdes. Faça um molho de iogurte com um toque de limão, gengibre, cúrcuma e mel.
#
# Quer que eu:
# - Busque fontes mais tradicionais e confiáveis (sites como Allrecipes, BBC Good Food, Food Network) e traga 3–5 receitas completas?
# - Crie uma versão personalizada que use exatamente todos os seus ingredientes (2–4 porções, com valores nutricionais estimados)?
# Diga qual caminho prefere e eu sigo!

# %%
response = agent.invoke(
    {"messages": [multimodal_question, HumanMessage(content="Qual dessas receitas é mais saudável? Responda em portugues")]},
    config
)

print(response)
# Out:
# {'messages': [HumanMessage(content=[{'type': 'text', 'text': 'Search recipes to me based on this ingredients'}, {'type': 'image', 'base64': '...', 'mime_type': 'image/png'}], additional_kwargs={}, response_metadata={}, id='6c414b7a-f962-492f-8467-85092d9116ad'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 431, 'prompt_tokens': 633, 'total_tokens': 1064, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cvot5Wo7tZm2mlecirTnTLBIKs8ae', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b9ed5-5a2d-7723-86b2-619e6c19e2ee-0', tool_calls=[{'name': 'search_recipes_by_ingredients', 'args': {'query': 'recipes with grapefruit, lemon, orange, kiwi, blueberries, almonds, yogurt, honey, ginger, turmeric'}, 'id': 'call_H6W04ieCfb7QBY3H3CAjNn14', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 633, 'output_tokens': 431, 'total_tokens': 1064, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}), ToolMessage(content='{"query": "recipes with grapefruit, lemon, orange, kiwi, blueberries, almonds, yogurt, honey, ginger, turmeric", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.instagram.com/reel/DRZ8vO6iFU8/", "title": "1 grapefruit 1 orange blueberries ginger (this is the perfect juice to ...", "content": "✨ Recipe Via @keila.aldamaa 1 grapefruit 1 orange blueberries ginger (this is the perfect juice to drink if you don\'t like the taste of ginger", "score": 0.6241337, "raw_content": null}, {"url": "https://www.facebook.com/groups/723028768102377/posts/1473206376417942/", "title": "Today\'s breakfast: Orange, grapefruit, kiwi, banana, cherry tomatoes ...", "content": "Breakfast immunity booster Ingredients for 1 bowl: 2 natural plant yogurts 3 c. s of lemon juice 1/2 c. It\'s turmeric powder 1 c. s of agave", "score": 0.6161283, "raw_content": null}, {"url": "https://www.instagram.com/reel/DHgsqSquJFz/?hl=en", "title": "Just 4 ingredients for a zesty little gut-loving wellness shot!  ☀️ All ...", "content": "!✨☀️ All you need! Fresh grapefruit juice Squeezed lemon Grated ginger ... Sunshine in a shot ☀️✨ Freshly pressed lemon, ginger, turmeric and", "score": 0.49187145, "raw_content": null}, {"url": "https://www.tiktok.com/@eatsbymike/video/7332515065679072543", "title": "Ginger & Turmeric Shots   50 g ginger 1 orange 1 lemon 7 g ... - TikTok", "content": "Then cut and juice an entire lemon and orange. and half of a lime. Add a few slices of pear leftover so I toss those into. fresh turmeric would", "score": 0.477238, "raw_content": null}, {"url": "https://www.kowalskis.com/recipes/breakfast-brunch/kiwi-grapefruit-salad?srsltid=AfmBOoqCm_yd05LI7lw0uAVcTn3SQFGddTmsq4-MQFF4YXnl5dfCgb7G", "title": "Kiwi Grapefruit Salad | Kowalski\'s Markets", "content": "Ingredients ; ¼ cup plain yogurt ; 1 tsp. Kowalski\'s Pure Honey ; ½ tsp. grated lime zest ; - freshly squeezed lime juice, to taste ; 3 kiwi, peeled and sliced (", "score": 0.44622982, "raw_content": null}], "response_time": 1.09, "request_id": "2911f86c-ee84-4f2f-a7e2-ead84a071d9b"}', name='search_recipes_by_ingredients', id='fe3c0660-6565-440c-8175-2123f43776bc', tool_call_id='call_H6W04ieCfb7QBY3H3CAjNn14'), AIMessage(content="Nice spread! I found several recipes that use citrus fruits plus yogurt, honey, ginger, turmeric, berries, and nuts. Here are good matches I pulled from a quick search:\n\n- Kiwi Grapefruit Salad | Kowalski's Markets\n  - Why it fits: kiwi, grapefruit, plain yogurt, honey; you can sprinkle almonds or add blueberries as toppings.\n  - Link: https://www.kowalskis.com/r ...
