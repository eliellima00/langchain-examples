# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from tavily import TavilyClient
from typing import Dict, Any
from langchain.tools import tool

tavily_client = TavilyClient()

@tool()
def web_search (query: str)-> Dict[str, Any]:
  """Search the web for information"""
  return tavily_client.search(query)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
       "travel_server": {
         "transport": "streamable_http",
         "url": "https://mcp.kiwi.com"
       }
    }
)

# %%
tools = await client.get_tools()

print(tools)
# Out:
# [StructuredTool(name='search-flight', description='\n# Search for a flight\n\n## Description\n\nUses the Kiwi API to search for available flights between two locations on a specific date.\n\n## How it works\n\nThe tool will:\n1. Search for matching locations to resolve airport codes\n2. Find available flights for the specified route and date range\n\n## Method\n\nCall this tool whenever a user wants to search for flights, regardless of whether they provided exact airport codes or just city names.\n\nYou should display the returned results in a markdown table format: Group the results by price (those who are the cheapest), duration (those who are the shortest, i.e. have the smallest \'totalDurationInSeconds\') and the rest (those that could still be interesting).\n\nAlways display for each flight in order:\n  - In the 1st column: The departure and arrival airports, including layovers (e.g. "Paris CDG → Barcelona BCN → Lisbon LIS")\n  - In the 2nd column: The departure and arrival dates & times in the local timezones, and duration of the flight (e.g. "03/08 06:05 → 09:30 (3h 25m)", use \'durationInSeconds\' to display the duration and not \'totalDurationInSeconds\')\n  - In the 3rd column: The cabin class (e.g. "Economy")\n  - (In case of return flight only) In the 4th column: The return flight departure and arrival airports, including layovers (e.g. "Paris CDG → Barcelona BCN → Lisbon LIS")\n  - (In case of return flight only) In the 5th column: The return flight departure and arrival dates & times in the local timezones, and duration of the flight (e.g. "03/08 06:05 → 09:30 (3h 25m)", use \'return.durationInSeconds\' to display the duration)\n  - (In case of return flight only) In the 6th column: The return flight cabin class (e.g. "Economy")\n  - In the previous-to-last column: The total price of the flight\n  - In the last column: The deep link to book the flight\n\nFinally, provide a summary highlighting the best prices, the shortest flights and a recommendation. End wishing a nice trip to the user with a short fun fact about the destination!\n', args_schema={'type': 'object', 'properties': {'flyFrom': {'type': 'string', 'minLength': 1, 'description': 'Location to fly from: It could be a city or an airport name or code'}, 'flyTo': {'type': 'string', 'description': 'Location to fly to: It could be a city or an airport name or code'}, 'departureDate': {'type': 'string', 'pattern': '^\\d{2}\\/\\d{2}\\/\\d{4}$', 'description': 'Departure date in dd/mm/yyyy format'}, 'departureDateFlexRange': {'type': 'integer', 'minimum': 0, 'maximum': 3, 'default': 0, 'description': 'Departure date flexibility range in days (0 to 3 days before/after the selected departure date)'}, 'returnDate': {'type': 'string', 'pattern': '^\\d{2}\\/\\d{2}\\/\\d{4}$', 'description': 'Return date in dd/mm/yyyy format'}, 'returnDateFlexRange': {'type': 'integer', 'minimum': 0, 'maximum': 3, 'default': 0, 'description': 'Return date flexibility range in days (0 to 3 days before/after the selected return date)'}, 'passengers': {'type': 'object', 'properties': {'adults': {'type': 'integer', 'minimum': 0, 'maximum': 9, 'default': 1, 'description': 'Number of adults (over 12 years old included)'}, 'children': {'type': 'integer', 'minimum': 0, 'maximum': 8, 'default': 0, 'description': 'Number of children (from 3 to 11 years old included)'}, 'infants': {'type': 'integer', 'minimum': 0, 'maximum': 4, 'default': 0, 'description': 'Number of infants (under 2 years old)'}}, 'additionalProperties': False, 'default': {'adults': 1, 'children': 0, 'infants': 0}, 'description': 'Passengers details. The total number of passengers must be between 1 and 9. There must be at least one adult. There must be at least one adult per infant.'}, 'cabinClass': {'type': 'string', 'enum': ['M', 'W', 'C', 'F'], 'description': 'Cabin class: M (economy), W (economy premium), C (business), F (first class)'}, 'sort': {'type': 'string', 'enum': ['price', 'duration', 'quality', 'date'], 'default' ...

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///advanced-agents/resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# # Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
  origin: str
  destination: str
  guest_count: str
  genre: str

# %% [markdown]
# # Creating SubAgents

# %%
from langchain.agents import create_agent

flight_agent = create_agent(
  model='gpt-5-nano',
  tools=tools,
  system_prompt="""
  Você é um agent de Viagens. Busca por voos para os locais mais desejados para casamentos.
  Você não esta autorizado a perguntar nenhuma questão a mais.
  Você deve buscar as melhores opções de voos baseados nos seguintes critérios:
  - Preço (menor, classe economica)
  - Duração (menor)
  - Data (periodo do ano em que você acredita que seja melhor para casamento neste local)
  Para tornar as coisas mais simples, busque apenas uma passagem, apenas ida.
  Você pode fazer multiplas buscas iterativamente até encontrar a melhor opção.
  Você não irá receber informações extras, apenas a origem e o destino. É seu trabalho pensar criticamente sobre a melhor opção.
  Uma vez que você encontrou a melhor opção, deixe o usuário saber sua "shortlist" de opções.
  """
)

# %%
wedding_avenue_agent = create_agent(
  model="gpt-5-nano",
  tools=[web_search],
  system_prompt="""
  Você é um especialista em encontrar espaços para casamento. Procure por espaços no local desejado, e com a capacidade de convidados desejados.
  Você não esta autorizado a perguntar nenhuma questão a mais.
  Você deve buscar as melhores opções de espaços para casamento baseados nos seguintes critérios:
  - Preço (menor)
  - Capacidade(quantia exata informada)
  - Avaliação (Mais avaliados)
  Você pode fazer multiplas buscas iterativamente até encontrar as melhores opções
  """
)

# %%
dj_agent = create_agent(
  model="gpt-5-nano",
  tools=[query_playlist_db],
  system_prompt="""
  Você é um especialista em playlists. Procure no banco de dados e faça a curadoria da playlist perfeita para um casamento com base no genero escolhido.
  Uma vez que você tiver a playlist, calcule o total da duração e custo da playlist. Cada música tem um preço associado.
  Se você encontrar erros quando estiver fazendo a busca no banco de dados, tente concertar eles fazendo alterações na query.
  Não volte de mãos vazias. Continue tentando fazer a query no banco de dados até que encontre a lista de músicas.
  Você pode precisar fazer multiplas buscas iterativamente para encontrar a melhor opção
  """
)

# %% [markdown]
# # Main Coordinator Agent

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def call_flight_agent(runtime: ToolRuntime)-> str:
  """Travel agent searches for flights to the desired destination wedding location."""
  origin = runtime.state["origin"]
  destination = runtime.state["destination"]
  
  response = await flight_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})

  return response["messages"][-1].content

@tool
def call_wedding_avenue_agent(runtime: ToolRuntime)-> str:
  """Venue agent chooses the best venue for the given location and capacity."""
  destination = runtime.state["destination"]
  guest_count = runtime.state["guest_count"]
  query = f"Find wedding venus in {destination} for {guest_count} guests"

  response = wedding_avenue_agent.invoke({"messages": [HumanMessage(content=query)]})

  return response["messages"][-1].content

@tool
def call_dj_agent(runtime: ToolRuntime) -> str:
  """DJ agent curates the perfect playlist for the given genre."""
  genre = runtime.state["genre"]
  query = f"Find {genre} tracks for wedding playlist"
  response = dj_agent.invoke({"messages": [HumanMessage(content=query)]})
  return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
  """Update the state when you know all of the values: origin, destination, guest_count, genre"""
  return Command(update={
    "origin": origin, 
    "destination": destination, 
    "guest_count": guest_count, 
    "genre": genre, 
    "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
  )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[call_flight_agent, call_wedding_avenue_agent, call_dj_agent, update_state],
    state_schema=WeddingState,
    system_prompt="""
    Você é um Coordenador de Planos de casamento. Você delega tarefas para seus especialistas em buscar voos, espaços para casamento e playlists
    Primeiro procure todas as informações que você precisa para atualizar o estado. Depois que estiver pronto, você pode delegar as tarefas.
    Uma vez que você tiver recebido suas respostas, coordene o casamento perfeito para mim.
    """
)

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
  {
    "messages": [HumanMessage(content="Estou em cuiaba e gostaria de um casamento em são paulo para 100 convidados, genero rock")]
  }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'São Paulo',
#  'genre': 'rock',
#  'guest_count': '100',
#  'messages': [HumanMessage(content='Estou em cuiaba e gostaria de um casamento em são paulo para 100 convidados, genero rock', additional_kwargs={}, response_metadata={}, id='bd74fc2e-857d-4b58-9313-89da4f04a075'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 744, 'prompt_tokens': 319, 'total_tokens': 1063, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cxa5pEYVqlzmDCNYgLMWVJJ9JMFjj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bb7da-cbc8-76c1-b037-8670a2b71df3-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'Cuiabá', 'destination': 'São Paulo', 'guest_count': '100', 'genre': 'rock'}, 'id': 'call_i6dX8qePUC42ZC52Xrz2xrwY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 319, 'output_tokens': 744, 'total_tokens': 1063, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='836a67c5-215d-463b-b7a4-f852c3e81753', tool_call_id='call_i6dX8qePUC42ZC52Xrz2xrwY'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 708, 'prompt_tokens': 367, 'total_tokens': 1075, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cxa5wsOKRrUoHMPte74SfOakKbA84', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bb7da-e749-7290-a417-0ac929b59fc5-0', tool_calls=[{'name': 'call_flight_agent', 'args': {}, 'id': 'call_CYKiPAdRPKMIT2EZrTpXpCA7', 'type': 'tool_call'}, {'name': 'call_wedding_avenue_agent', 'args': {}, 'id': 'call_jtEiyDd2E0xYuSypnK1uQDXd', 'type': 'tool_call'}, {'name': 'call_dj_agent', 'args': {}, 'id': 'call_hn7ihekA8MiCIT1kbgR0TdQf', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 367, 'output_tokens': 708, 'total_tokens': 1075, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Aqui está a shortlist de voos de Cuiabá (CGB) para São Paulo (GRU ou VCP), em uma viagem só de ida, classe econômica, considerando opções mais baratas e também as mais rápidas.\n\n| Saída (rota) | Horário local (partida → chegada) | Classe | Retorno (rota) | Horário local (retorno) | Classe retorno | Preço | Link de reserva |\n|---|---|---|---|---|---|---|---|\n| CGB → GRU | 14/10/2026 15:20 → 14/10/2026 18:35 (2h15m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/3vRzXb |\n| CGB → GRU | 15/10/2026 15:20 → 15/10/2026 18:35 (2h15m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/9qNabw |\n| CGB → GRU | 17/10/2026 02:00 → 17/10/2026 05:15 (2h15m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/fKfuSr |\n| CGB → GRU | 15/10/2026 02:00 → 15/10/2026 05:15 (2h15m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/1hy6Fw |\n| CGB → GRU | 17/10/2026 15:20 → 17/10/2026 18:35 (2h15m) | Economy | — | — | — | 48 EUR | https://on.kiwi.com/nkKuIF |\n| CGB → VCP | 14/10/2026 11:05 → 14/10/2026 14:05 (2h) | Economy | — | — | — | 54 EUR | https://on.kiwi.com/FibQ79 |\n| CGB → VCP | 14/10/2026 16:40 → 14/10/2026 19:40 (2h) | Economy | — | — | — | 54 EUR | https://on.kiwi.com/GLPpHR |\n| CGB → GRU | 14/10/2026 06:00 → 14/10/2026 08:15 (2h) | Economy | — | — | — | 54 EUR | https://on.kiwi.com/p8emII |\n| CGB → VCP | 14/10/2026 12:10 → 14/10/2026 14:15 (2h) | Economy | — | — | — | 54 EUR | https://on.kiwi.com/QtghrR |\n| CGB → VCP | 14/10/2026 22:55 → 15/10/2026 01:00 (2h) | Economy | — | — | — | 54 EUR | https://on.kiwi.com/e032nH |\n\nNotas rápidas:\n- A menor tarifa disponível na busca é 48 EUR (Economy), com várias datas entre 14 e 17 de outubro de 2026 para GRU.\n- As opções mais rápidas aparecem com duração de 2h (7200 segundos), com tarifas entre 54–56 EUR.\n- Os voos são de ida única, sem retorno incluído nesta shortlist.\n- Moeda informada: EUR (converte conforme seu modo de pagamento ao completar a reserva).\n\nDesejo uma ótima viagem! Fun fact: São Paulo é a maior cidade do Brasil e da América do Sul em população, além de possuir uma das maiores redes de restaurantes do mundo. Se estiver planejando uma lua de mel rápida, Cuiabá fica bem perto do Pantanal, um destino incrível para natureza e aventura. Excelente casamento!', name='call_flight_agent', id='ccf8e39e-efc9-4e20-9852-618b845c6933', tool_call_id='call_CYKiPAdRPKMIT2EZrTpXpCA7'),
#               ToolMessage(content='Aqui vão as melhores opções de espaços para casamento em São Paulo que atendem 100 convidados, ordenadas para facilitar o preço (mais baixo quando há informações), com a capacidade informada e Indicates de avaliações.\n\n1) Espaço Villarys\n- Capacidade informada: até 250 convidados (apropriado para 100, incluso)\n- Preço (informação disponível): pacote completo para 100 convidados a partir de cerca de R$ 21.900; pacote premium por volta de R$ 25.000\n- Avaliações: presença de várias avaliações em sites de Casamentos (bom histórico de feedback)\n- Observação: espaço amplo, costuma oferecer tudo incluído (buffet, decoração, dj/etc.) em pacotes.\n\n2) Espaço Vilares (Guarulhos, SP)\n- Capacidade informada: até 200 convidados\n- Preço (informação disponível): pacote completo para 100 convidados por volta de R$ 25.000 (pacote premium divulgado)\n- Avaliações: atividades e posts públicos indicam serviços completos; presença de conteúdo em redes sociais com feedback dos clientes\n- Observação: buffet completo incluído; espaço moderno e bem localizado\n\n3) Espaço Quintal (SP)\n- Capacidade informada: 70 a 150 convidados (inclui 100)\n- Preço: não informado publicamente nos resultados\n- Avaliações: disponível em guia de espaços, com foco em wedding rustic; boa reputação para casamentos intimistas\n- Observação: ideal para casamento ao ar livre ou com layout rústico; atende 100 convidados dentro da faixa de capacidade\n\n4) Marriott Executive Apartments São Paulo\n- Capacidade informada: até 100 convidados\n- Preço: sob consulta (pacotes sob medida)\n- Avaliações: rede de hotéis da Marriott costuma ter avaliações elevadas; serviço de hotelaria premium\n- Observação: opção de mini-wedding com infraestrutura de hotel (versátil para casamento intimista)\n\n5) Centro de Eventos São Luís (São Paulo)\n- Capacidade informada: até 100 convidados (conforme espaço Santo Inácio disponível dentro do Centro de Eventos)\n- Preço: não publicado publicamente\n- Avaliações: espaço de eventos com variedade de salões\n- Observação: local central para quem quer um espaço dedicado para eventos com capacidade de 100\n\nCaso prefira, posso seguir buscando opções com foco em:\n- espaços com preço ainda mais baixo (pacotes básicos)\n- opções com avaliações mais extensas (mais de X avaliações)\n- locais com disponibilidade em datas específicas\n\nObservação rápida sobre ofertas: opções como Espaço Villarys e Espaço Vilares já aparecem com pacotes inclusos para 100 convidados em variações de preço (aprox. 21.900 a 25.000), o que tende a colocá-las entre as opções mais acessíveis entre espaços com capacidade para 100 em SP.', name='call_wedding_avenue_agent', id='228c7167-44bc-4c9e-aef6-88d46453961d', tool_call_id='call_jtEiyDd2E0xYuSypnK1uQDXd'),
#               ToolMessage(content="Ótimo! Segue uma curadoria de rock voltada para clima de casamento, com faixas disponíveis no nosso banco de dados. Optei por baladas e rock mais voltado à celebração (românticas com bom apelo de dança).\n\nPlaylist curada (10 faixas)\n\n1) Love In An Elevator — Aerosmith — Album: Big Ones — Duração: 5:21 — Preço: 0.99\n2) Rag Doll — Aerosmith — Album: Big Ones — Duração: 4:24 — Preço: 0.99\n3) What It Takes — Aerosmith — Album: Big Ones — Duração: 5:10 — Preço: 0.99\n4) Cryin' — Aerosmith — Album: Big Ones — Duração: 5:09 — Preço: 0.99\n5) Amazing — Aerosmith — Album: Big Ones — Duração: 5:56 — Preço: 0.99\n6) Crazy — Aerosmith — Album: Big Ones — Duração: 5:16 — Preço: 0.99\n7) Angel — Aerosmith — Album: (dados do álbum não exibidos no conjunto) — Duração: 5:07 — Preço: 0.99\n8) All I Really Want — Alanis Morissette — Album: Jagged Little Pill — Duração: 4:44 — Preço: 0.99\n9) You Oughta Know — Alanis Morissette — Album: Jagged Little Pill — Duração: 4:09 — Preço: 0.99\n10) Perfect — Alanis Morissette — Album: Jagged Little Pill — Duração: 3:08 — Preço: 0.99\n\nTotais\n- Duração total da playlist: 2.904 segundos = 48 minutos e 24 segundos (48:24)\n- Custo total: 10 faixas × 0,99 = 9,90 (USD)\n\nObservações\n- As faixas estão classificadas como Rock, com vibe romântica/celebratória que funciona bem em momentos de dança e celebração no casamento.\n- O item 7 (Angel) mostra o álbum como data/registro indisponível no conjunto de dados; se quiser, posso substituir por outra faixa romântica de rock disponível.\n- Se quiser mais opções com ritmo mais dançante, ou mais baladas suaves para cerimônia, eu adapto a lista.\n\nDeseja ajustes? Posso criar versões com mais/menos faixas, ou priorizar apenas baladas, ou incluir faixas de outras bandas de rock que combinem com o estilo do seu casamento.", name='call_dj_agent', id='9423449e-776d-4d54-b9c0-35a8b67942b6', tool_call_id='call_hn7ihekA8MiCIT1kbgR0TdQf'),
#               AIMessage(content='Ótimo! Já atualizei o estado e já recebi as opções dos nossos especialistas. Segue um resumo objetivo e os próximos passos para fecharmos tudo com você.\n\nResultados até agora\n\n1) Voos Cuiabá (CGB) → São Paulo (GRU ou VCP) para 100 convidados (ida)\n- Opções rápidas e econômicas (todas são ida única, em EUR):\n  - CGB → GRU, 14/10/2026, 15:20 → 18:35, 2h15m, Economy, ~48 EUR\n    link: https://on.kiwi.com/3vRzXb\n  - CGB → GRU, 15/10/2026, 15:20 → 18:35, 2h15m, Economy, ~48 EUR\n    link: https://on.kiwi.com/9qNabw\n  - CGB → GRU, 17/10/2026, 02:00 → 05:15, 2h15m, Economy, ~48 EUR\n    link: https://on.kiwi.com/fKfuSr\n  - CGB → GRU, 15/10/2026, 02:00 → 05:15, 2h15m, Economy, ~48 EUR\n    link: https://on.kiwi.com/1hy6Fw\n  - CGB → GRU, 17/10/2026, 15:20 → 18:35, 2h15m, Economy, ~48 EUR\n    link: https://on.kiwi.com/nkKuIF\n  - CGB → VCP, 14/10/2026, 11:05 → 14:05, 2h, Economy, ~54 EUR\n    link: https://on.kiwi.com/FibQ79\n  - CGB → VCP, 14/10/2026, 16:40 → 19:40, 2h, Economy, ~54 EUR\n    link: https://on.kiwi.com/GLPpHR\n  - (e outras opções de 14/10 a 17/10 com tarifas entre 54 EUR)\n- Observação: são opções de ida, com tarifas em euro, com links de reserva. Posso consolidar um grupo de assentos para 100 viajantes se você quiser bloquear.\n\n2) Espaços para casamento em São Paulo (100 convidados)\n- 1) Espaço Villarys (SP)\n  - Capacidade: até 250; adequado para 100\n  - Pacote completo para 100 convidados: a partir de ~R$ 21.900; pacote premium ~R$ 25.000\n  - Avaliações: feedback positivo; costuma incluir buffet, decoração, DJ, etc.\n- 2) Espaço Vilares (Guarulhos, SP)\n  - Capacidade: até 200\n  - Pacote completo para 100 convidados: por volta de R$ 25.000 (pacote premium)\n  - Avaliações: serviços completos; buffet incluso; espaço moderno\n- 3) Quintal (SP)\n  - Capacidade: 70–150 (inclui 100)\n  - Preço público: não informado\n  - Observação: vibe rústica/ao ar livre; bom para 100 convidados\n- 4) Marriott Executive Apartments São Paulo\n  - Capacidade: até 100\n  - Preço: sob consulta (pacotes sob medida)\n  - Observação: opção premium, com infraestrutura de hotel\n- 5) Centro de Eventos São Luís (São Paulo)\n  - Capacidade: até 100\n  - Preço: não publicado publicamente\n  - Observação: centro de eventos com várias salas; boa opção central\n\n3) Playlist rock para casamento (curadoria inicial)\n- 10 faixas sugeridas (rock com vibe romântica/celebração):\n  1) Love In An Elevator — Aerosmith\n  2) Rag Doll — Aerosmith\n  3) What It Takes — Aerosmith\n  4) Cryin’ — Aerosmith\n  5) Amazing — Aerosmith\n  6) Crazy — Aerosmith\n  7) Angel — Aerosmith (observação: pode substituir se houver indisponibilidade)\n  8) All I Really Want — Alanis Morissette\n  9) You Oughta Know — Alanis Morissette\n  10) Perfect — Alanis Morissette\n- Total aprox. 48 minutos de música listada; custo estimado de faixas: varia conforme licença de uso.\n- Observação: podemos adaptar para mais baladas suaves para cerimônia, ou incluir faixas de outras bandas de rock bem adequadas ao clima de casamento.\n\nPróximos passos sugeridos\n\nA. Definir datas e destino de voos\n- Qual janela de datas você prefere para o casamento (por exemplo, fim de semana entre 14 e 18 de outubro de 2026, como as opções sugeridas)?\n- Você quer:\n  - bloquear 1 ou 2 opções de voo para o grupo de 100 viajantes (com ou sem conexão, GRU ou VCP)?\n  - ou preferiria que eu busque opções com diferentes horários/datas para comparar?\n\nB. Confirmar o espaço\n- Qual(is) espaço(s) você quer priorizar: Villarys (SP) e Vilares (Guarulhos) entram como opções principais pela relação custo/estrutura?\n- Você já tem uma data-alvo? Prefere que eu verifique disponibilidade de cada espaço para a data desejada e traga orçamentos formais?\n\nC. Catálogo musical\n- Quer manter a curadoria atual como base e expandir com mais 5–15 faixas para ter uma lista maior?\n- Deseja separar trilha para cerimônia (entrada, troca de alianças, etc.) e para a recepção/da ...
#  'origin': 'Cuiabá'}

# %%
print(response["messages"][-1].content)
