# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
  user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
  """Generate system prompt based on user role."""
  user_language = request.runtime.context.user_language
  base_prompt = "Your are a helpfull assistant."

  if user_language != "English":
    return f"{base_prompt} only respond in {user_language}."
  elif user_language == "English":
    return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
  {"message": [HumanMessage(content="Hello, how are you?")]},
  context=LanguageContext(user_language="Portuguese")
)

print(response["messages"][-1].content)
# Out:
# Olá! Em que posso ajudar hoje? Diga o que você precisa (explicações, revisão de texto, sugestões de código, ajuda com tarefas, planilhas, ideias criativas, etc.) e o nível de detalhe desejado.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# ¡Hola! Hablaré en español. ¿En qué puedo ayudarte hoy? Puedo asistir con preguntas, explicaciones, redacción, resúmenes, traducciones, ideas, programación y mucho más. Si tienes una consulta específica, compártela y te ayudo.
